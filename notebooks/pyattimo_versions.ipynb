# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "../")

from motiflets.competitors import *
from motiflets.plotting import *

import pandas as pd
import seaborn as sns

import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import warnings
warnings.simplefilter("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# dataset = "scalability_n_FingerFlexionECoG_10_pyattimo_delta_0.5.csv"
# dataset = "scalability_n_Bird12-Week3_2018_1_10_10_pyattimo_delta_0.5.csv"
# dataset = "scalability_n_CinC_Challenge_10_pyattimo_delta_0.5.csv"
dataset = "scalability_n_Challenge2009TestSetA_101a_10_pyattimo_delta_0.5.csv"

paths = {
    "dev9": "../tests/attimo/pyattimo_dev9/",    
    "dev10": "../tests/attimo/pyattimo_dev10/",
    "dev12": "../tests/attimo/pyattimo_dev12/"
}

df_all = pd.DataFrame()
for name in paths:
    df = pd.read_csv(paths[name] + dataset)
    df["version"] = name
    df_all = pd.concat([df_all, df], ignore_index=True)

display(df_all)
# Out:
#     length  motif length               backend     time in s   memory in MB  \
# 0   440001          8192  pyattimo (delta=0.5)      9.482030    8840.121094
# 1   440001          4096  pyattimo (delta=0.5)      2.716128    7883.890625
# 2   440001          2048  pyattimo (delta=0.5)      2.996444    7886.890625
# 3   440001          1024  pyattimo (delta=0.5)      7.161896    7886.890625
# 4   440001           512  pyattimo (delta=0.5)      3.772819    7893.890625
# 5   440001          8192  pyattimo (delta=0.5)     10.038115    1415.984375
# 6   440001          4096  pyattimo (delta=0.5)      3.784200    1415.984375
# 7   440001          2048  pyattimo (delta=0.5)      4.065315    1415.984375
# 8   440001          1024  pyattimo (delta=0.5)      8.671942    1415.984375
# 9   440001           512  pyattimo (delta=0.5)      4.961441    1415.984375
# 10  440001          8192  pyattimo (delta=0.5)  12689.362941  226179.484375
# ...

# %%
ax = sns.barplot(y="time in s", x="version", hue="motif length", data=df_all, palette="muted")
ax.set_title(dataset)
plt.yscale('log')
plt.show()
